# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_excel("Job Trends.xlsx")

# %%
df.head()
# Out:
#                            Job Role              Company     City   State  \
# 0  Analyst, Healthcare Analyst, SQL                Lensa  Orlando      FL
# 1                Business Analyst I  Centene Corporation      NaN      FL
# 2                  Business Analyst           Kforce Inc  Orlando      FL
# 3                  Business Analyst  BackInTheBlack, LLC   Remote  Remote
# 4  Business Intelligence Analyst 1                   WEX      NaN   Maine
#
#                                      Job Description  \
# 0  Develop ad-hoc reports using SQL programming, ...
# 1  Perform various analysis and interpretation to...
# 2   Execute complex initiatives to implement and ...
# 3  As a Business Analyst you will interact with s...
# 4  Proactively identify and analyze key sales per...
#
#                                   Eligibility/Skills  Platform
# 0  2-4 years increasingly complex database and da...  Linkedin
# 1  Bachelor’s degree in related field or equivale...  Linkedin
# 2   Bachelor's degree is required in Business or ...  Linkedin
# 3  B.S. or Associate degree in Computer Science, ...  Linkedin
# 4  \nBachelor's degree in Business Administration...  Linkedin

# %%
#Converting all the text to Lower case and removing punctuations for skills and job description

df ['Eligibility/Skills'] = (df ['Eligibility/Skills']
                             .astype(str)
                             .str.lower()
                             .str.replace(r'[^\w\s]', '', regex=True))
df ['Job Description'] = (df ['Job Description']
                             .astype(str)
                             .str.lower()
                             .str.replace(r'[^\w\s]', '', regex=True))
df.head()
# Out:
#                            Job Role              Company     City   State  \
# 0  Analyst, Healthcare Analyst, SQL                Lensa  Orlando      FL
# 1                Business Analyst I  Centene Corporation      NaN      FL
# 2                  Business Analyst           Kforce Inc  Orlando      FL
# 3                  Business Analyst  BackInTheBlack, LLC   Remote  Remote
# 4  Business Intelligence Analyst 1                   WEX      NaN   Maine
#
#                                      Job Description  \
# 0  develop adhoc reports using sql programming sq...
# 1  perform various analysis and interpretation to...
# 2   execute complex initiatives to implement and ...
# 3  as a business analyst you will interact with s...
# 4  proactively identify and analyze key sales per...
#
#                                   Eligibility/Skills  Platform
# 0  24 years increasingly complex database and dat...  Linkedin
# 1  bachelors degree in related field or equivalen...  Linkedin
# 2   bachelors degree is required in business or m...  Linkedin
# 3  bs or associate degree in computer science inf...  Linkedin
# 4  \nbachelors degree in business administration ...  Linkedin

# %%
# Removing stop words like "a, the, is, and, an" for eliminating noise 
# nltk is Natural Language Toolkit that performs text mining
import nltk
nltk.corpus.stopwords
df.head()
# Out:
#                            Job Role              Company     City   State  \
# 0  Analyst, Healthcare Analyst, SQL                Lensa  Orlando      FL
# 1                Business Analyst I  Centene Corporation      NaN      FL
# 2                  Business Analyst           Kforce Inc  Orlando      FL
# 3                  Business Analyst  BackInTheBlack, LLC   Remote  Remote
# 4  Business Intelligence Analyst 1                   WEX      NaN   Maine
#
#                                      Job Description  \
# 0  develop adhoc reports using sql programming sq...
# 1  perform various analysis and interpretation to...
# 2   execute complex initiatives to implement and ...
# 3  as a business analyst you will interact with s...
# 4  proactively identify and analyze key sales per...
#
#                                   Eligibility/Skills  Platform
# 0  24 years increasingly complex database and dat...  Linkedin
# 1  bachelors degree in related field or equivalen...  Linkedin
# 2   bachelors degree is required in business or m...  Linkedin
# 3  bs or associate degree in computer science inf...  Linkedin
# 4  \nbachelors degree in business administration ...  Linkedin

# %%
from collections import Counter
jd_counter = Counter(df['Job Description'])
skill_counter = Counter(df['Eligibility/Skills'])
jd_counter
# Out:
# Counter({'nan': 2,
#          'develop adhoc reports using sql programming sql server reporting services ssrs medinsight rxnavigator crystal reports executive dashboard and other analytic  programming tools as needed \ngenerate and distribute standard reports on schedule using sql excel and other reporting software \ncollects and documents report  programming requirements from requestors to ensure appropriate creation of reports and analyses uses peertopeer review process and enduser consultation to reduce report writing errors and rework \nidentify and complete report enhancementsfixes modify reports in response to approved change requests retain old and new report design for audit trail purposes \nanalyze data sets and trends for anomalies outliers trend changes and opportunities \ncreate comprehensive workflows for the production and distribution of assigned reports document reporting processes and procedures \nassist with completion of special projects as requested by various internal departments or in support of requests from regulatory agencies contracting agencies or other external organizations \ndemonstrate healthcare experience in quantifying measuring and analyzing financial and utilization metrics of healthcare ': 1,
#          'perform various analysis and interpretation to link business needs and objectives for assigned function\n\nsupport business initiatives through data analysis identification of implementation barriers and user acceptance testing of new systems\nidentify and analyze user requirements procedures and problems to improve existing processes\nperform detailed analysis on assigned projects recommend potential business solutions and assist with implementation\nperforms other duties as assigned\ncomplies with all policies and standards': 1,
#          ' execute complex initiatives to implement and support productpricing strategies across ecommerce and ticketing platforms\n learns functionality of new software systems eg sap commerce horizon ticketing system and solutions provided by digital and technology combining that knowledge with business requirements from marketing  sales digital  technology finance global product  pricing loss prevention attractions operations and entrance operations to develop efficient and repeatable solutions to meet the business needs\n complete initial setup and configuration of new systems in all environments working closely with digital  technology vendors and quality engineering to understand requirements and implementing solutions that are appropriate based on system functionality and udxs standards troubleshoot issues to identify root cause and remediate appropriately either directly or through other teams\n complete endtoend testing of new systems to ensure that elements that require indepth understanding of the configuration and functionality are verified to be functioning as expected escalate defects found to vendor andor digital  technology teams with sufficient detail to aide in issue reproduction and root cause identification collaborate on potential fixes and verify that resolution provides the expected functionality\n analyze endtoend process for bringing products to life and identify areas for efficiency to enable quicker speed to market for new product launches and price changes leverage advanced technical skills to develop automation by utilizing available resources in existing systems eg application interfaces database updates alongside programming abilities eg sql visual basic python to develop test and implement solutions that can be leveraged by less technically skilled team members': 1,
#          'as a business analyst you will interact with subject matter experts sme development teams and project management to gather analyze document and develop requirements for software development you will be responsible for researching information obtaining artifacts and interviewing smes pertaining to the project scope this includes analyzing documenting and organizing all pertinent information obtained during discovery and creating functional specifications in cross functional team working sessions\n\n\nhow will you do it\n\nanalyze business and functional requirements through documentation review interaction with team members and interviews with smes\ncreate user stories use cases flow diagrams mapping documents and other artifacts to facilitate working session discussions creation of technical specifications test cases and user manuals\nwrite queries to extract business rules and system configurations in support of development and configuration initiatives\ndocument configurations and calculations in a business readable format for businessclient consumption \nstay current on the core bitb software and standalone applications built managed and maintained by the company\ntrack update and interact with the project tracking tool jira and provide updates to the project management team on project status\ncommunicate and interact with other departments as projects move through the sdlc to ensure success of the projects\ncreate proof of concepts andor outofthebox configurations to accompany new development modules which support configuration\nwork with the configuration manager on the design and configuration approach with new modules for postproduction maintenance and usage': 1,
#          'proactively identify and analyze key sales performance indicators kpis such as conversion rates pipeline velocity and sales cycle length to uncover trends and areas for improvement\ncreatively support the development and implementation of datadriven sales strategies and initiatives by providing analytical insights and recommendations\nindependently conduct adhoc data analysis and generate reports to answer specific business questions and support strategic decisionmaking\nefficiently document data processes reporting methodologies and dashboard configurations for knowledge sharing and maintainability\ncollaboratively partner with sales leadership sales operations colleagues and other departments to understand their data needs and translate them into actionable reporting solutions\nadapt youre at ease in a fastpaced environment and are able to change direction rapidly when priorities deadlines or personalities shift \neffectively communicate whether its verbal or written you present information and ideas in a clear and professional manner you understand your audience and can easily shift your communication style so it is understandable to all': 1,
#          'primary support contact and expert for powerbi erecruit and business central reporting\nenhance existing reportsdashboards to improve performance and presentation\ndelivers reporting solutions by developing and creating new reports to support each department\ndevelops validates and provides ongoing support of operational and projectrelated reports scripts and data analysis\nprovides technical direction guidance and assistance during project development maintaining data integrity and quality control of delivered reports\ndevelops maintains and optimizes database modules and system components\nsupports business decisions by developing and institutionalizing data driven analytics as defined by smes\ndata analytics\n\nanalyze and interpret data to provide actionable insights and recommendations\nperform data cleaning validation and manipulation to ensure accuracy and consistency\nuse statistical techniques to identify trends patterns and anomalies in the data\ncollaboration and support\n\nwork with business stakeholders to understand their requirements and translate them into technical specifications\nprovide support and training to endusers on power bi features and report functionalities\ncollaborate with it and data teams to ensure data integrity and optimal performance\ndocumentation and best practices\n\ndocument development processes data sources and reporting methodologies\nimplement best practices for data visualization and reporting to ensure clarity and usability\nconform with and abide by all regulations policies work procedures safety rules and instructions\nperform additional duties as assigned': 1,
#          'analyze business processes and systems to identify improvement opportunities and develop solutions\nserve as a liaison between business stakeholders and technical teams\ngather document and validate business and functional requirements\nsupport implementation and integration efforts of microsoft dynamics and salesforce platforms\ncreate detailed reports dashboards and presentations using ms excel powerpoint and other office tools\nassist in user acceptance testing and training initiatives\nmonitor project progress identify risks and propose mitigation strategies\ncontinuously evaluate business performance and recommend enhancements': 1,
#          'analyze and document business requirements and processes\nwork closely with business stakeholders subject matter experts and software developers to design and develop software solutions\ncollaborate with internal business stakeholders and subject matter experts to elicit business rules identify and implement process improvements conduct root cause analysis and perform system investigations\ncreate workflows process documentation use cases activity diagrams and other business process modeling methods and tools as applicable\nmanage projects and initiatives from start to finish ensuring deliverables are met on time and within budget\nconduct quality assurance and user acceptance testing and ensure software solutions meet business requirements\ndevelop and maintain technical documentation\nstay up to date with industry trends and best practices\ncommunicate effectively with crossfunctional teams and stakeholders\nprovide technical subject matter expertise to detail out change orders and expanded scope\nconduct system training for company users\nperforms other related duties as assigned': 1,
#          'business analysis planning and monitoring how business analysts determine which activities are necessary in order to complete a business analysis effort\nstakeholder identification selection of business analysis techniques process that will be used to manage requirements and how to access the progress of the work \nbuilds relationships with business partners including users project team and management at all levels \ndevelops a communication plan to meet the needs of all business partners and can adapt communication style to different audiences\nutilizes basic techniques to measure quality of business analysis and helps to implement change based on the metrics\nrequirements management and communications how business analysts manage conflicts issues and changes in order to ensure that stakeholders and the project team remain in agreement on the solution scope how requirements are communicated to stakeholders and how knowledge gained by the business analyst is maintained for future use\nmanage changes to requirements and provide basic assessment of impact to scope of projects \nmanage conflicts and collaborates with project team to gain consensus \ndevelops and maintains traceability of the requirements on smaller projects from planning through postproduction phases of projects to ensure quality of delivery\nunderstands and can apply basic reuse standards for maintaining requirements\ncreates comprehensive requirements artifacts at the level of details to support development of solution\nfacilitate reviews of requirements using formal and informal techniques for small projects and mods\nelicitation how business analysts work with stakeholders to identify and understand their needs and the environment in which they work\nability to use the analysis techniques identified in planning to accurately flush out requirements \nhelps other senior analysts determine when additional information is needed to discover requirements that the stakeholder is not aware of\naccurately documents the requirements so that the stakeholders understand and can review\nvalidates the requirements are what the stakeholders intended in order to meet their needs\nenterprise analysis identify business needs refine and clarify the definition of the needs and validate the solution meets the needs\ncan provide basic problem definition and analysis helps with business case development feasibility and definition of the scope\nhelp stakeholders identify areas of opportunity and facilitates exploration \nhas a good understanding of business functions such as service and operations sales and distribution compliance etc\n understands organizational culture and uses relationships to influence decisions at a project level\nrequirements analysis how business analysts prioritize and progressively elaborate stakeholder and solution requirements in order to enable the project team to implement a solution that will meet the needs of the organization and stakeholders \nsolution assessment assess proposed solution to determine which solution best fits the business need identify gaps in solution and determine necessary workarounds or changes to the solution\nvalidates the solution meets the functonality that the business needs \nprocess analysis utilize process modeling tools and techniques in order to identify and breakdown phases of a process in order to create an understanding of the inputs outputs and operations that take place during each phase\nuser acceptance develop acceptance criteria to ensure business needs are met ': 1,
#          'as a bi analyst within the pharmacy services finance business intelligence automation  analytics organization youll have the opportunity to become a trusted consultant to the cfo organization deriving meaning and insights from a massive amount of financial data leveraging industry leading technology youll be tasked with designing dashboards and data visualizations used by stakeholders across the enterprise to drive profitability expense efficiency and other key financial measurements youll also have the opportunity to dive deeper into the data at cvs health leveraging sound research and analysis to drive tactical and strategic decision making\n\n\ndesign dashboards and data visualizations with a focus on usability and speedtoinsight\ncollaborate with internal finance stakeholders to determine the analytical needs of the organization\npartner with data engineering colleagues to develop new analytics products in an effective and efficient manner\ndevelop holistic semantic layer data sources enabling multiple solutions from a singular source\nensure developed solutions are of sound quality consistently available and performing to expectations\ndrive continuous improvement by automating and streamlining existing technical processes\nrespond timely to adhoc needs for data and reporting as necessary to support the larger finance organization': 1,
#          'maintains a thorough understanding of distribution to assist the process manager with facilitating the designrevision of distribution supply chain procedures and application development by applying knowledge of problem solving and process improvement pspi to analyze and design the process\ncollaborates with process manager  industrial engineer to ensure distribution center dc processes and systems are working properly to meet user and business needs\nprovides tier 1 distribution center support by monitoring the infor supply chain execution sce hotline to resolve system and process issues solicits help from it and vendors when necessary escalates issues to appropriate stakeholders when needed\nassists in the development and refinement of business applications that meet user needs translate requests into system functional requirements communicates requests to system analysts andor application developers\npartners with the quality control supervisors to ensure ongoing documentation of business needs processes and applications by utilizing a consistent documentation format and procedures': 1,
#          'lead andor participate in requirements gathering and analysis sessions with clients to determine project requirements\n\n able to elicit and identify project requirements from internal and external client end users\n\n responsible for validating requirements by providing option comparisons and justifications\n\n capable of providing gap analysis and needs assessments to uncover business need\n\n accountable for reviewing and finalizing extensive functional and technical documentation\n\n able to elicit and translate highlevel business needs into specific and concise processes\n\n proficient in testing to ensure successful execution and appropriate application of solutions\n\n can provide highlevel projectstatus updates and prepared reports to designated recipients\n\n accountable for selforganization and tracking completion of assigned tasks including successful delivery of assigned project milestones\n\n prepare and present training content to clients as needed\n\n creation of project documentation to include user manuals training deliverables business requirements documentation test scripts and work product validation': 1,
#          'infosys is seeking a business analyst in wealth management domain as a consultant you will be an expert contributing to different phases of the consulting lifecycle you will be intensely involved in business process consulting you will define the problem propose and create the solution you will also play an important role in the development configuration and deployment of the overall solution you will guide teams on project processes deliverables and contribute to the proposal development client training and internal capability building and help detail the project scope you will have the opportunity to shape valueadding consulting solutions that enable our clients to meet the changing needs of the global landscape\n\ncandidate must be located within commuting distance of minneapolis mn or charlotte nc or be willing to relocate to the area': 1,
#          'the business analyst plays a crucial role in supporting homeserves strategic initiatives by analyzing business needs and translating them into actionable requirements this position is essential for ensuring that business processes align with organizational goals and optimize efficiency by gathering documenting and analyzing stakeholder input and requirements to support key decisionmaking processes\n\nin this role the business analyst collaborates closely with stakeholders and project teams to identify business challenges and opportunities responsibilities involve conducting data analysis facilitating requirements gathering sessions developing business cases facilitatinggoverning user acceptance testing and assisting in the implementation of business process improvements the role demands analytical thinking an inquisitive mind the ability to see outside the box as well as the skill to probe and extract details that others may not see problemsolving capabilities and a detailed understanding of business operations to drive effective solutions and deliver tangible business benefits\n\n\nresponsibilities\n\nbusiness requirements gathering\n\nfacilitate workshops and brainstorming sessions with stakeholders to gather comprehensive business requirements using techniques such as interviews surveys and document analysis\ntranslate complex business needs into clear detailed specifications and requirements for technical teams ensuring solutions effectively address business challenges\ndata analysis and reporting\n\nconduct thorough analysis of data from diverse sources to identify patterns trends and insights that can inform strategic decisions and improve business operations\nprepare detailed reports and visual presentations that effectively communicate insights and recommendations to various stakeholders driving informed business decisions\nstakeholder collaboration\n\nestablish strong working relationships with stakeholders to deeply understand their objectives constraints and opportunities for business improvements\nencourage open communication and collaboration between teams to align efforts towards achieving the companys strategic objectives\nproject support\n\nassist in the creation of business cases and feasibility studies to prioritize projects based on their potential impact and alignment with strategic objectives\nfacilitate user acceptance testing as well as governance for alignment to sox compliance\nsupport project teams during the implementation of solutions providing analytical insights and ensuring solutions meet business needs and enhance efficiency\nprocess improvement\n\nanalyze current business processes to identify inefficiencies and bottlenecks and propose modifications to enhance operational effectiveness\ndevelop actionable improvement plans and work collaboratively with teams to implement changes ensuring improvements are sustainable and aligned with business goals': 1,
#          'serve all stakeholders with integrity humility and joy while consistently modeling the importance of both task competency and relationships\nparticipate in company events activities and meetings with a smile and an infectious great attitude\nelicit analyze and document business requirements to develop solutions\nidentify and assess current processes to find areas of improvement and optimizations\nfacilitate improvements in procedures workflows and processes\nimprove business operational efficiency\nconduct processmapping rootcause analysis and workshop to gather requirements and assess current processes\ntranslate business needs into clear technical requirements using user stories diagrams and requirement specifications\nvalidate business requirements through testing and analysis to ensure proposed solutions meet documented needs and quality standards\ncontinuously engage stakeholders and teams to ensure processes align with improvements\nsupport the creation of business rules through defined process and procedure that are in alignment with company goals and objectives\nbridge the gap between business needs and technical requirements to achieve project goals\nprepare and present outcomes to stakeholders and leaders across the business and\nall other duties as assigned': 1,
#          'mettel is a global communications solutions provider with the most complete suite of fully managed services that focus on secure connectivity and network and mobility services we simplify communications and networking for business and government agencies our customers include many of the fortune 500 and gartner recognizes us as an industry leader we have the broadest portfolio of technology and integrated partnerships as well as our private network which we use to create tailored solutions design deployment and ongoing management driving cost savings efficiency innovation and the ability to focus on core objectives\n\nwe believe that each team member is a key to the success and sustainability of the group in order to achieve this we offer an environment where all professionals can grow and develop their skills and competencies collaborate with diverse professionals share knowledge and enjoy a rewarding career\n\n\nwe are seeking a talented highly motivated individual to join our business insights team at our new york headquarters the ideal candidate will have a love of data and proficiency in researching customizing exacting evaluating identifying trends managing and translating data into actionable business insights\n\n\nwithin this role you will\n\ncollaborate with crossfunctional teams including product management sales finance customer success and senior leadership to capture key data and identify datadriven insights\nanalyze and interpret large and complex data sets related to business performance account growth and product usage etc\ncreate and develop detailed financial models and analysis to support various strategic initiatives including market analysis customer segmentation product usage etc\ncreate and deliver highimpact reports and interactive dashboards that intuitively communicate or visualize key insights to senior leadership\ncreate and deliver executive sales dashboards for monthly review by senior leadership\nassess and process map methodologies to identify and implement data governance innovative workflows or efficiencies to enhance our data mining efforts': 1,
#          'as part of an agile squad the analyst will be examining business systems and processes to identify user needs document requirements and address operational issues they will collaborate with a squad leader to build prioritize and maintain product backlog in order to focus the team on delivering business solutions with the highest impact to desired outcomes where appropriate they will translate business requirements to technical resources in support of helping develop business solutions that reduce risk improve business efficiency and minimize impact the successful candidate will be capable of performing in a fast paced deadline driven environment\n\nthe expertise you have\nexpertise in various business analysis methodologies including data analysis uses case development story writing and user acceptance testing and product documentation\n\nproven ability to translate business vision into defined and prioritized narratives for the team backlog': 1,
#          'discover your opportunity with mitsubishi ufj financial group mufg one of the worlds leading financial groups across the globe were 120000 colleagues striving to make a difference for every client organization and community we serve we stand for our values building longterm relationships serving society and fostering shared and sustainable growth for a better world\n\nwith a vision to be the worlds most trusted financial group its part of our culture to put people first listen to new and diverse ideas and collaborate toward greater innovation speed and agility this means investing in talent technologies and tools that empower you to own your career\n\njoin mufg where being inspired is expected and making a meaningful impact is rewarded\n\nthe selected colleague will work at an mufg office or client sites four days per week and work remotely one day a member of our recruitment team will provide more details\ntranslating clients requirements to functional documentation participating in technical designs and test planning participating in the review analysis and documentation of business systems and user needs developing documents for it applications system specifications and test plans according to existing standards and methodologies designing prototyping coding and testing new or enhanced applications supporting the collection documentation and maintenance of functional requirements and modeling eliciting the requirements needed to carry out business processes including interviews intelligence analysis and survey assessments performing customer support processes and activities for the implementation of new or existing applications participating in the planning execution and documentation of functional testing results translating business needs processes and procedures into a workable system and articulating on specific software requirements by communicating about these requirements with technology experts and business stakeholders monitoring the efficiency and effectiveness of application operations and troubleshooting problems as necessary assisting in the development and delivery of training sessions and demos for end users working closely with business architects and other technology staff to deliver project results while implementing risk analysis and meeting required deliverable': 1,
#          'affiliate renewals contribute to the dmvpd renewals by helping the team  deal lead from the team gather inputs for financial modeling\n\nhome entertainment departmental prepare any materials such as qbr to help build home ent business expertise for pd strategy  sales team across east and west coast\n\nairlines content licensing deal support for the 30 airlines content licensing deals and routine rates evaluation in line with market\n\ndeal renewal contribute to the renewal of home entertainment deals mainly local partners and select wholesale deals\n\nreporting maintain trackers and create weekly reports for senior leadership updates': 1,
#          'essential duties and responsibilities\n\n\n\nproactively generate new business opportunities within the designated territory\nconsistently meet or exceed monthly and quarterly sales quotas\ncontinuously expand knowledge of the industry trends new products services and broker practices\nstay informed about competitors initiatives and analyze potential competitive threats\nensure the accuracy timeliness and efficiency of all services provided to assigned clients\noversee the preparation and execution of renewal proposals and processes for existing clients\nprepare concise and impactful executive summaries for client presentations\ndevelop lead generation strategies and effectively use crm salesforce to track activities\ncomplete and submit accurate new business paperwork expense reports and weekly activity reports by the deadlines set by management\nparticipate in monthly consulting meetings and provide training and coaching to other team members\nfrequent domestic and occasional international travel will be required to attend team onsite meetings customer events industry conferences and training sessions this may include air travel ground transportation including cars taxis or rideshare services and in some cases potential public transportation': 1,
#          'gather requirements from business units and translate those to programmers and developers\n confer with clients regarding the nature of the information processing or computation needs\n prepare costbenefit and returnoninvestment analyses to aid in decisions on system implementation\n interview or survey workers observe job performance or perform the job to determine what information is processed and how it is processed\n coordinate and link the computer systems within an organization to increase compatibility and so information can be shared\n consult with management to ensure agreement on system principles\n expand or modify system to serve new purposes or improve work flow': 1,
#          'assess business requirements and develop an understanding of currentstate processes through interviews workshops and observations\ndocument requirements and user stories using agile methodologies and standard tools such as a requirements traceability matrix\ncreate detailed process designs business rules and flow diagrams using visio or similar tools\ndevelop and execute test scenarios and cases for system and integration testing\npartner with project managers and business stakeholders to ensure deliverables meet scope schedule and quality expectations\nparticipate in user training sessions and assist in creating user documentation and reference materials\ncollaborate with product owners program managers and it teams to ensure alignment between business goals and technical delivery\nidentify and implement process improvements and support change management efforts\nserve as a liaison between business and technology teams to ensure clear communication and issue resolution\nsupport resource planning and contribute to complete actionable project plans': 1,
#          'documentation for reporting requirements\ndata validation\ncreate testing scenarios for preuat and uat for the reporting\nsupport execution of scenarios  testing during uat with the business\nmaintain the issues tracker and provide weekly status updates on the testing\ncomplete uat and exit criteria with the different business groups\nsupport the first few stages of deployment to ensure stability\nbusiness communication\ncoordination of activities with the report development team': 1,
#          'we are seeking a detailoriented technical business analyst to join our it department this role will serve as a bridge between business stakeholders and technical teams analyzing business requirements and translating them into technical solutions that drive organizational efficiency and growth the role with work closely with our business stakeholders to translate complex business requirements into it delivered products it takes an individual with enthusiasm and drive to build enterprise atscale solutions\nmore importantly  success in the role will be guided by your critical thinking and decisionmaking abilities': 1,
#          'daily technical and functional support of meter reading and field service applications\nconduct usage and system problem analysis and resolution at local and remote locations\ndevelop and document the problem resolution with internal and external technical resources\ninterface with end users on existing business processes\nidentify user information requirements and develop adhoc sql queries for analysis and translate results into custom report specifications': 1,
#          'translate business needs into measurable requirements for development and testing\ndefine business requirements create specifications and propose datadriven solutions\nreview and validate test plans to confirm solutions meet expectations\nsupport qa activities as needed\npartner with technical and engineering teams to ensure solutions meet strategic needs\nlead or support crossfunctional teams on adoption user experience and dataprocess flows\nprovide input into product lifecycle activities including new features and user education\nwork with regulatory smes to identify and document regulatory requirements\nconduct requirement reviews with stakeholders and document formal acceptance': 1,
#          'process analysis and improvement core banking  debit cards\n\n collaborate with internal stakeholders and clients to understand business processes related to debit card issuance authorization transaction processing settlement and disputes\n analyze endtoend workflows across core banking and card systems to identify inefficiencies pain points and opportunities for automation or optimization\n use industrystandard business process modeling techniques eg bpmn to document asis and tobe processes\n define kpis to measure success eg transaction success rate dispute turnaround time card activation rate fraud detection rate\n2 requirements gathering and technical documentation\n\n lead workshops and stakeholder interviews to elicit functional and nonfunctional requirements\n translate business needs into clear detailed process documentation use cases brds and functional specifications\n work closely with technology teams to ensure business needs are properly translated into technical requirements for core banking systems middleware and card networks\n ensure alignment with technical protocols like iso 8583 soaprest apis and data file formats used in card processing\n3 stakeholder collaboration  vendor engagement\n\n act as a liaison between business users it compliance operations and card processor partners eg visa dps tsys fis jack henry\n facilitate crossfunctional meetings and decisionmaking forums to ensure stakeholder alignment\n build trusted relationships across departments and advise on industry best practices in debit card operations routing optimization and fraud controls\n4 solution design and implementation\n\n support solution architecture for enhancements to card systems or banking platforms eg integration of virtual debit cards contactless support or mobile wallet provisioning\n partner with developers and qa teams to support implementation and testing of new card products or processing enhancements\n design and execute user acceptance testing uat and postimplementation validation\n deliver enduser training and onboarding documentation for new workflows\n5 compliance risk and continuous improvement\n\n ensure process designs adhere to relevant regulatory frameworks eg reg e durbin amendment pci dss\n monitor process kpis and system logs to identify bottlenecks or anomalies proactively\n conduct postlaunch reviews and contribute to a culture of continuous improvement\n stay current with industry trends including embedded finance realtime payments and card network innovations': 1,
#          'lead collection capture and management of mission user needs from prioritization through concept development and user story writing to support development and deployment\n facilitate the gathering of business focused requirements to support a product team and product owner in defining the backlog and ensuring the users perspective is considered\n focus requirements gathering on improved usability user experience and driving user adoption and engagement\n identify core business needs and decompose and document in concepts of operation story maps briefings and user stories document business rules and construct workflow diagrams as needed\n provide consultation on complex projects while considering the business implications of the application of technology to the current and future business environment': 1})

# %%
df_jd_counter = pd.DataFrame(jd_counter.items(), columns=['JD', 'Total_count'])
df_jd_counter.head()
# Out:
#                                                   JD  Total_count
# 0  develop adhoc reports using sql programming sq...            1
# 1  perform various analysis and interpretation to...            1
# 2   execute complex initiatives to implement and ...            1
# 3  as a business analyst you will interact with s...            1
# 4  proactively identify and analyze key sales per...            1

# %%
df_skill_counter = pd.DataFrame(skill_counter.items(), columns=['Skills', 'Total_count'])
df_skill_counter.head()
# Out:
#                                               Skills  Total_count
# 0  24 years increasingly complex database and dat...            1
# 1  bachelors degree in related field or equivalen...            1
# 2   bachelors degree is required in business or m...            1
# 3  bs or associate degree in computer science inf...            1
# 4  \nbachelors degree in business administration ...            1

# %% [markdown]
# ## Wordcloud to see the most often repeated word

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from wordcloud) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl (301 kB)
#    ---------------------------------------- 0.0/301.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/301.2 kB ? eta -:--:--
#    -- ------------------------------------ 20.5/301.2 kB 320.0 kB/s eta 0:00:01
#    ------- ------------------------------- 61.4/301.2 kB 656.4 kB/s eta 0:00:01
#    ---------------------------------------- 301.2/301.2 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
#   WARNING: The script wordcloud_cli.exe is installed in 'C:\Users\vishh\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import re
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# 1️⃣ Define custom stopwords (same as before)
custom_stopwords = set(STOPWORDS)
custom_stopwords.update([
    'experience', 'knowledge', 'ability', 'skills', 'skill', 'year', 'years', 'required', 'preferred',
    'excellent', 'strong', 'understanding', 'familiarity', 'management', 'proficiency', 
    'including', 'environment', 'tools', 'work', 'problem', 'solving', 'communication',
    'degree', 'bachelor', 'masters', 'related', 'education', 'field', 'team', 'support'
])

# 2️⃣ Combine all words into text form (if using Counters, you can join keys)
jd_text = ' '.join(jd_counter.keys()).lower()
skills_text = ' '.join(skill_counter.keys()).lower()

# 3️⃣ Keep only meaningful technical/business terms using regex
# (Add more as needed based on your dataset)
allowed_pattern = r'\b(sql|python|power\s?bi|tableau|excel|r|data|analysis|report|dashboard|kpi|requirement|stakeholder|visual|jira|agile|scrum|sap|business|system|process|gap|testing|documentation|insight|project)\b'

jd_filtered = ' '.join(re.findall(allowed_pattern, jd_text))
skills_filtered = ' '.join(re.findall(allowed_pattern, skills_text))

# 4️⃣ Generate cleaned word clouds
wordcloud_jd = WordCloud(width=800, height=400, background_color='white', 
                         stopwords=custom_stopwords, colormap='plasma').generate(jd_filtered)

wordcloud_skills = WordCloud(width=800, height=400, background_color='white', 
                             stopwords=custom_stopwords, colormap='viridis').generate(skills_filtered)

# 5️⃣ Display both
fig, ax = plt.subplots(1, 2, figsize=(15, 6))
ax[0].imshow(wordcloud_jd, interpolation='bilinear')
ax[0].set_title('Top Keywords in Job Descriptions (Refined)', fontsize=14)
ax[0].axis('off')

ax[1].imshow(wordcloud_skills, interpolation='bilinear')
ax[1].set_title('Top Skills in Eligibility Section (Refined)', fontsize=14)
ax[1].axis('off')

plt.show()

# %% [markdown]
# ## Frequency Bar chart for Top Skills

# %%
# Combine text from columns into one string
jd_text = ' '.join(df['Job Description'].astype(str).tolist()).lower()
skill_text = ' '.join(df['Eligibility/Skills'].astype(str).tolist()).lower()

# Define a pattern to capture meaningful technical/business words
pattern = r'\b(sql|python|excel|tableau|power\s?bi|r|dashboard|kpi|requirement|stakeholder|visual|jira|agile|scrum|sap|visio|business|system|process|gap|testing|documentation|insight|report|tableau|master\s|finance|health|information\?system\s|communication|management|Azure|Devops|visualbasic|waterfall|lifecycle|modeling|flowchart)\b'

# Find all matches
jd_words = re.findall(pattern, jd_text)
skill_words = re.findall(pattern, skill_text)

# Count word frequencies
jd_counter = Counter(jd_words)
skill_counter = Counter(skill_words)

# Convert to DataFrames
df_jd_counter = pd.DataFrame(jd_counter.items(), columns=['Skill', 'Count']).sort_values(by='Count', ascending=False)
df_skill_counter = pd.DataFrame(skill_counter.items(), columns=['Skill', 'Count']).sort_values(by='Count', ascending=False)

# Select top 10
top_jd = df_jd_counter.head(10)
top_skills = df_skill_counter.head(10)

# Plot
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Job Description chart
ax[0].barh(top_jd['Skill'], top_jd['Count'], color='orchid')
ax[0].invert_yaxis()
ax[0].set_title('Top 10 Keywords in Job Descriptions', fontsize=14)
ax[0].set_xlabel('Frequency')

# Eligibility chart
ax[1].barh(top_skills['Skill'], top_skills['Count'], color='skyblue')
ax[1].invert_yaxis()
ax[1].set_title('Top 10 Skills in Eligibility Section', fontsize=14)
ax[1].set_xlabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insights with location and other parameters

# %%
df.columns = [c.strip() for c in df.columns]

# --- Normalize text fields ---
df['Eligibility/Skills'] = df['Eligibility/Skills'].fillna('').astype(str).str.lower()
df['Job Description'] = df['Job Description'].fillna('').astype(str).str.lower()
df['City'] = df['City'].fillna('Unknown').astype(str)
df['State'] = df['State'].fillna('Unknown').astype(str)

# --- Define skill patterns and normalization map ---
# Add or edit entries according to your data
skill_patterns = {
    r'\b(power[\s\-]?bi|ms[\s\-]?power[\s\-]?bi)\b': 'Power BI',
    r'\b(tableau)\b': 'Tableau',
    r'\b(sql|mysql|postgres|postgresql|sql\s*server|oracle)\b': 'SQL',
    r'\b(python)\b': 'Python',
    r'\b(\br\b|\br[\s,]|\br$)': 'R',
    r'\b(excel|ms\s*excel|advanced\s*excel|vlookup|xlookup|pivot)\b': 'Excel',
    r'\b(power\s*dax|dax)\b': 'DAX',
    r'\b(python|pandas|numpy|scikit[-\s]?learn)\b': 'Python (Data)',
    r'\b(aws|amazon\s*web\s*services)\b': 'AWS',
    r'\b(azure|microsoft\s*azure)\b': 'Azure',
    r'\b(etl|talend|informatica|airbyte|fivetran|glue|ssis|azure\s*data\s*factory)\b': 'ETL Tools',
    r'\b(snowflake)\b': 'Snowflake',
    r'\b(alteryx)\b': 'Alteryx',
    r'\b(sas)\b': 'SAS',
    r'\b(power\s*apps|power\s*platform)\b': 'Power Platform',
    r'\b(business\s*analysis|business\s*analyst|business\s*analysis)\b': 'Business Analysis',
    r'\b(data\s*visuali[sz]ation|visualization|visualisation|dashboard|data\s*viz)\b': 'Data Visualization',
    r'\b(kpi|key\s*performance\s*indicator)\b': 'KPI',
    r'\b(communication|stakeholder|presentation)\b': 'Communication/Stakeholder',
    r'\b(agile|scrum|kanban|safe)\b': 'Agile',
    r'\b(jira|confluence|trello|asana|monday)\b': 'Project Tools',
    # add more domain-specific terms you expect
}

# precompile regexs for speed
compiled = [(re.compile(pat, flags=re.I), rep) for pat, rep in skill_patterns.items()]

# --- Function to extract normalized skills from text (eligibility/skills + job description optionally) ---
def extract_skills_from_text(text):
    found = []
    # replace punctuation with space to avoid merging words
    text = re.sub(r'[^\w\s]', ' ', text.lower())
    for pattern, label in compiled:
        if pattern.search(text):
            # Count occurrences (optional - here we just note presence)
            occurrences = len(pattern.findall(text))
            # append label occurrence times so frequency reflects repeats if desired
            found.extend([label] * occurrences)
    return found

# --- Apply extraction row-wise to eligibility/skills (you can include job description too) ---
# If eligibility/skills is a comma-separated list already, these will be found by patterns above.
df['extracted_skills'] = df['Eligibility/Skills'].apply(extract_skills_from_text)

# Optional: also look into job description if you want combined counts
# df['extracted_skills'] += df['job description'].apply(extract_skills_from_text)

# --- Explode into one-row-per-skill per job posting ---
df_exploded = df.explode('extracted_skills').dropna(subset=['extracted_skills']).copy()
df_exploded.rename(columns={'extracted_skills': 'skill'}, inplace=True)

# --- Aggregate counts by skill and location ---
# Overall skill frequency
skill_freq = df_exploded['skill'].value_counts().reset_index()
skill_freq.columns = ['skill', 'count']

# Skill frequency by city (or state) - choose whichever granularity you prefer
by_city_skill = df_exploded.groupby(['City', 'skill']).size().reset_index(name='count')

# For plotting readability, pick top N skills overall, and top M cities by total postings
TOP_SKILLS = 10
TOP_CITIES = 8

top_skills = skill_freq.head(TOP_SKILLS)['skill'].tolist()
top_cities = df['City'].value_counts().head(TOP_CITIES).index.tolist()

# Filter the city-skill table to those sets
by_city_skill_filt = by_city_skill[by_city_skill['skill'].isin(top_skills) & by_city_skill['City'].isin(top_cities)]

# pivot for stacked/grouped bar plotting
pivot = by_city_skill_filt.pivot(index='skill', columns='City', values='count').fillna(0)

# --- Plot 1: Overall top skills ---
plt.figure(figsize=(10, 6))
sns.barplot(data=skill_freq[skill_freq['skill'].isin(top_skills)], y='skill', x='count', palette='viridis')
plt.title('Top Skills (Overall)')
plt.xlabel('Frequency')
plt.ylabel('')
plt.tight_layout()
plt.show()

# --- Plot 2: Top Skills by City (stacked-like grouped bars) ---
plt.figure(figsize=(12, 6))
pivot.plot(kind='bar', stacked=False)  # stacked=False shows grouped bars; set True for stacked
plt.title('Top Skills by City (Top skills & Top cities)')
plt.xlabel('Skill')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='City', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()

# --- Extra insight: skill -> top cities table ---
skill_city_table = by_city_skill_filt.sort_values(['skill','count'], ascending=[True, False])
print("Top locations per skill (filtered):")
print(skill_city_table.groupby('skill').head(5).to_string(index=False))
# Out:
# C:\Users\vishh\AppData\Local\Temp\ipykernel_16196\1604431699.py:86: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=skill_freq[skill_freq['skill'].isin(top_skills)], y='skill', x='count', palette='viridis')
# Top locations per skill (filtered):
#        City                     skill  count
#      Remote                     Agile      2
#   Charlotte                     Agile      1
#       Tampa                     Agile      1
#   Charlotte         Business Analysis      1
#      Dublin         Business Analysis      1
#      Remote         Business Analysis      1
#       Tampa         Business Analysis      1
#      Remote Communication/Stakeholder      4
#      Dublin Communication/Stakeholder      1
#    McKinney Communication/Stakeholder      1
#     Orlando Communication/Stakeholder      1
# San Antonio Communication/Stakeholder      1
#     Unknown                     Excel      2
#   Charlotte                     Excel      1
#     Orlando                     Excel      1
#      Remote                     Excel      1
# San Antonio                     Excel      1
#      Remote             Project Tools      5
# San Antonio             Project Tools      2
#       Tampa             Project Tools      2
#     Orlando                    Python      1
#     Orlando             Python (Data)      1
#     Orlando                       SQL      2
#   Charlotte                       SQL      1
#      Remote                       SQL      1
#       Tampa                       SQL      1
#      Remote                   Tableau      1
#     Unknown                   Tableau      1

# %%
# Skill frequency by city (or state) - choose whichever granularity you prefer
by_city_skill = df_exploded.groupby(['State', 'skill']).size().reset_index(name='count')

# For plotting readability, pick top N skills overall, and top M cities by total postings
TOP_SKILLS = 10
TOP_STATES = 10

top_skills = skill_freq.head(TOP_SKILLS)['skill'].tolist()
top_state = df['State'].value_counts().head(TOP_STATES).index.tolist()

# Filter the state-skill table to those sets
by_state_skill_filt = by_city_skill[by_city_skill['skill'].isin(top_skills) & by_city_skill['State'].isin(top_cities)]

# pivot for stacked/grouped bar plotting
pivot = by_state_skill_filt.pivot(index='skill', columns='State', values='count').fillna(0)

# --- Plot: Top Skills by State (stacked-like grouped bars) ---
plt.figure(figsize=(12, 6))
pivot.plot(kind='bar', stacked=False)  # stacked=False shows grouped bars; set True for stacked
plt.title('Top Skills by City (Top skills & Top states)')
plt.xlabel('Skill')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='State', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()
